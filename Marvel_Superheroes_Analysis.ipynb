# %% [markdown]
# <a href="https://colab.research.google.com/github/Shatabdi-766/Data-Analysis-Project/blob/main/Marvel_Superheroes_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
marvel = pd.read_csv('/content/drive/MyDrive/Marvel/charcters_stats.csv')

# %%
marvel
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 4        Abomination       bad            63        80     53          90
# ..               ...       ...           ...       ...    ...         ...
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
# 610             Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %%
marvel.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %%
marvel.tail()
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
# 610             Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 606     12      14    164
# 607     31      28    182
# 608     83      28    388
# 609    100      56    292
# 610     72      28    288

# %%
marvel.shape
# Out:
# (611, 9)

# %%
marvel['Alignment'].value_counts() # check frequency of categories
# Out:
# good       432
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %%
marvel['Alignment']== 'good' #extract categorical value and boolean output
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 606     True
# 607     True
# 608     True
# 609     True
# 610    False
# Name: Alignment, Length: 611, dtype: bool

# %%
good = marvel[marvel['Alignment']== 'good'] # super extract categorical alignment value and boolean output
good
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 6        Adam Monroe      good            63        10     12         100
# ..               ...       ...           ...       ...    ...         ...
# 604            X-Man      good            88        53     53          95
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 0       25      52    233
# ...

# %%
good.head()
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 6  Adam Monroe      good            63        10     12         100     71
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 6      64    320

# %%
good.sort_values(by=['Speed'],ascending=False) # maximum numerical method top of the level
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 231       Flash III      good            63        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 295         Impulse      good            50        10    100          60
# 525        Stardust      good            88        85    100         110
# 447     Quicksilver      good            63        28    100          60
# ..              ...       ...           ...       ...    ...         ...
# 280       Hellstorm      good             1         1      1           1
# 445         Quantum      good             1         1      1           1
# 277   Hawkwoman III      good             1         1      1           1
# 276    Hawkwoman II      good             1         1      1           1
# 405           Namor      good             1         1      1           1
#
#      Power  Combat  Total
# 231     83      32    348
# 304     70      30    348
# ...

# %%
good.sort_values(by=['Speed'],ascending=False).head() # maximum numerical method top of the level
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 231       Flash III      good            63        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 295         Impulse      good            50        10    100          60
# 525        Stardust      good            88        85    100         110
# 447     Quicksilver      good            63        28    100          60
#
#      Power  Combat  Total
# 231     83      32    348
# 304     70      30    348
# 295     63      60    343
# 525    100      85    568
# 447     57      56    364

# %%
max_speed_good = good[good['Speed']==100] # maximum speed of good in 100
max_speed_good
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 85       Black Bolt      good            75        67    100          84
# 229         Flash I      good            63        10    100          50
# 230        Flash II      good            63        10    100          60
# 231       Flash III      good            63        10    100          60
# 232        Flash IV      good            63        10    100          32
# 295         Impulse      good            50        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 333          Krypto      good             9        80    100          90
# 418            Nova      good            38        60    100         100
# 447     Quicksilver      good            63        28    100          60
# 525        Stardust      good            88        85    100         110
# 537        Superman      good           100       100    100         100
#
# ...

# %%
min_speed_good = good[good['Speed']==1] # minimum speed of good in 1
min_speed_good
# Out:
#                  Name Alignment  Intelligence  Strength  Speed  Durability  \
# 7        Adam Strange      good             1         1      1           1
# 8           Agent  13      good             1         1      1           1
# 13       Alex Woolsly      good             1         1      1           1
# 15   Allan Quatermain      good             1         1      1           1
# 18     Ando Masahashi      good             1         1      1           1
# ..                ...       ...           ...       ...    ...         ...
# 580            Vulcan      good             1         1      1           1
# 584           Warbird      good             1         1      1           1
# 591       White Queen      good             1         1      1           1
# 595           Wiz Kid      good             1         1      1           1
# 601            Wondra      good             1         1      1           1
#
#      Power  Combat  Total
# 7        0       1      5
# ...

# %%
good.sort_values(by=['Power'],ascending=False) # maximum numerical method top of the level
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 609         Zatanna      good            75        10     23          28
# 546            Thor      good            69       100     92         100
# 511           Spawn      good            75        60     50          90
# 69    Beta Ray Bill      good            63        80     35          95
# 70         Beyonder      good            88       100     23         100
# ..              ...       ...           ...       ...    ...         ...
# 127       Bumbleboy      good             1         1      1           1
# 124  Brother Voodoo      good             1         1      1           1
# 415     Nite Owl II      good             1         1      1           1
# 120         Box III      good             1         1      1           1
# 100     Blaquesmith      good             1         1      1           1
#
#      Power  Combat  Total
# 609    100      56    292
# 546    100      85    546
# ...

# %%
good.sort_values(by=['Power'],ascending=False).head() # maximum numerical method top of the level
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 609        Zatanna      good            75        10     23          28
# 546           Thor      good            69       100     92         100
# 511          Spawn      good            75        60     50          90
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
#
#      Power  Combat  Total
# 609    100      56    292
# 546    100      85    546
# 511    100      95    470
# 69     100      84    457
# 70     100      56    467

# %%
max_power_good = good[good['Power']==100] # maximum power of good in 100
max_power_good
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69       Beta Ray Bill      good            63        80     35          95
# 70            Beyonder      good            88       100     23         100
# 85          Black Bolt      good            75        67    100          84
# 129              Cable      good            88        48     23          56
# 185            Deadman      good            50        10     33         100
# 196        Doctor Fate      good            81        16     25          80
# 198     Doctor Strange      good           100        10     12          84
# 204       Dr Manhattan      good            88        32     42          95
# 226          Firestorm      good            50        53     58          56
# 251               Goku      good            56       100     75          90
# 266         Hal Jordan      good            63        90     53          64
# ...

# %%
max_power_good.shape
# Out:
# (33, 9)

# %%
min_power_good = good[good['Power']==0] # maximum power of good in 0
min_power_good
# Out:
#                  Name Alignment  Intelligence  Strength  Speed  Durability  \
# 7        Adam Strange      good             1         1      1           1
# 8           Agent  13      good             1         1      1           1
# 13       Alex Woolsly      good             1         1      1           1
# 15   Allan Quatermain      good             1         1      1           1
# 18     Ando Masahashi      good             1         1      1           1
# ..                ...       ...           ...       ...    ...         ...
# 580            Vulcan      good             1         1      1           1
# 584           Warbird      good             1         1      1           1
# 591       White Queen      good             1         1      1           1
# 595           Wiz Kid      good             1         1      1           1
# 601            Wondra      good             1         1      1           1
#
#      Power  Combat  Total
# 7        0       1      5
# ...

# %%
min_power_good.shape
# Out:
# (134, 9)

# %%
good[good['Name']=='Goku'] # Analysis entire dataframe
# Out:
#      Name Alignment  Intelligence  Strength  Speed  Durability  Power  Combat  \
# 251  Goku      good            56       100     75          90    100     100
#
#      Total
# 251    521

# %%
good_max_power = good.sort_values(by=['Total'],ascending=False)
good_max_power
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 537           Superman      good           100       100    100         100
# 525           Stardust      good            88        85    100         110
# 546               Thor      good            69       100     92         100
# 536          Supergirl      good            94        98     92         100
# ..                 ...       ...           ...       ...    ...         ...
# 325       Kid Flash II      good             1         1      1           1
# 166   Crimson Dynamo I      good             1         1      1           1
# 312      Johann Krauss      good             1         1      1           1
# 95      Black Widow II      good             1         1      1           1
# 421         Omniscient      good             1         1      1           1
#
#      Power  Combat  Total
# 361    100      85    581
# ...

# %%
good_max_power.head()
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 361  Martian Manhunter      good           100       100     96         100
# 537           Superman      good           100       100    100         100
# 525           Stardust      good            88        85    100         110
# 546               Thor      good            69       100     92         100
# 536          Supergirl      good            94        98     92         100
#
#      Power  Combat  Total
# 361    100      85    581
# 537     94      85    579
# 525    100      85    568
# 546    100      85    546
# 536     85      75    544

# %%
plt.figure(figsize=(8,5))
plt.bar(list(good_max_power['Name'])[0:5],list(good_max_power['Total'])[0:5],color='g')
plt.show()

# %%
bad = marvel[marvel['Alignment']== 'bad'] # super extract categorical alignment value and boolean output
bad
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 4       Abomination       bad            63        80     53          90
# 5           Abraxas       bad            88       100     83          99
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 17             Ammo       bad             1         1      1           1
# ..              ...       ...           ...       ...    ...         ...
# 586            Warp       bad            38        10     23          28
# 590       Weapon XI       bad             1         1      1           1
# 593  Willis Stryker       bad            38        16     23          28
# 605     Yellow Claw       bad             1         1      1           1
# 610            Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 4       55      95    436
# 5      100      56    526
# ...

# %%
bad.head()
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 11   Air-Walker       bad            50        85    100          85    100
# 16        Amazo       bad            75       100    100         100    100
# 17         Ammo       bad             1         1      1           1      0
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5

# %%
bad.sort_values(by=['Speed'],ascending=False) # maximum numerical method top of the level
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 610             Zoom       bad            50        10    100          28
# 11        Air-Walker       bad            50        85    100          85
# 16             Amazo       bad            75       100    100         100
# 535   Superboy-Prime       bad            94       100    100         100
# 242      General Zod       bad            94       100     96         100
# ..               ...       ...           ...       ...    ...         ...
# 256  Granny Goodness       bad             1         1      1           1
# 254      Goliath III       bad             1         1      1           1
# 503         Siren II       bad             1         1      1           1
# 154      Cheetah III       bad             1         1      1           1
# 153       Cheetah II       bad             1         1      1           1
#
#      Power  Combat  Total
# 610     72      28    288
# ...

# %%
bad.sort_values(by=['Speed'],ascending=False).head() # maximum numerical method top of the level
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 610            Zoom       bad            50        10    100          28
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
#
#      Power  Combat  Total
# 610     72      28    288
# 11     100      40    460
# 16     100     100    575
# 535    100      85    579
# 242     94      95    579

# %%
max_speed_bad = bad[bad['Speed']==100] # maximum speed of bad in 100
max_speed_bad
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 535  Superboy-Prime       bad            94       100    100         100
# 610            Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 11     100      40    460
# 16     100     100    575
# 535    100      85    579
# 610     72      28    288

# %%
max_speed_bad.shape
# Out:
# (4, 9)

# %%
mid_speed_bad = bad[bad['Speed']==96] # maximum speed of bad in 100
mid_speed_bad
# Out:
#             Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 242  General Zod       bad            94       100     96         100     94
#
#      Combat  Total
# 242      95    579

# %%
min_speed_bad = bad[bad['Speed']==1] # maximum speed of bad in 100
min_speed_bad
# Out:
#                  Name Alignment  Intelligence  Strength  Speed  Durability  \
# 17               Ammo       bad             1         1      1           1
# 21             Angela       bad             1         1      1           1
# 27         Anti-Spawn       bad             1         1      1           1
# 67             Beetle       bad             1         1      1           1
# 75      Billy Kincaid       bad             1         1      1           1
# 78           Bird-Man       bad             1         1      1           1
# 79        Bird-Man II       bad             1         1      1           1
# 83       Black Abbott       bad             1         1      1           1
# 103          Blizzard       bad             1         1      1           1
# 104        Blizzard I       bad             1         1      1           1
# 109       Bloodwraith       bad             1         1      1           1
# ...

# %%
min_speed_bad.shape
# Out:
# (44, 9)

# %%
bad.sort_values(by=['Intelligence'],ascending=False) # maximum numerical method top of the level
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
# 338       Lex Luthor       bad           100        10     12          14
# 336           Leader       bad           100        10     12          14
# 122         Brainiac       bad           100        28     63          90
# 194      Doctor Doom       bad           100        32     20         100
# ..               ...       ...           ...       ...    ...         ...
# 460      Redeemer II       bad             1         1      1           1
# 154      Cheetah III       bad             1         1      1           1
# 153       Cheetah II       bad             1         1      1           1
# 152        Cheetah I       bad             1         1      1           1
# 461     Redeemer III       bad             1         1      1           1
#
#      Power  Combat  Total
# 386    100      28    277
# ...

# %%
bad.sort_values(by=['Intelligence'],ascending=False).head() # maximum numerical method top of the level
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
# 338       Lex Luthor       bad           100        10     12          14
# 336           Leader       bad           100        10     12          14
# 122         Brainiac       bad           100        28     63          90
# 194      Doctor Doom       bad           100        32     20         100
#
#      Power  Combat  Total
# 386    100      28    277
# 338     10      28    174
# 336     58      42    236
# 122     60      75    416
# 194     93      84    429

# %%
max_intelligence_bad = bad[bad['Intelligence']==100] # maximum speed of bad in 100
max_intelligence_bad
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 29     Apocalypse       bad           100       100     33         100    100
# 122      Brainiac       bad           100        28     63          90     60
# 194   Doctor Doom       bad           100        32     20         100     93
# 315         Joker       bad           100        10     12          56     22
# 321          Kang       bad           100        48     58          70     71
# 336        Leader       bad           100        10     12          14     58
# 338    Lex Luthor       bad           100        10     12          14     10
# 360      Mandarin       bad           100        28     23          28     99
# 449  Ra's Al Ghul       bad           100        28     32          42     27
# 465       Riddler       bad           100        10     12          14     10
# 555      Tinkerer       bad           100        10     23          14     10
#
#      Combat  Total
# ...

# %%
max_intelligence_bad.shape
# Out:
# (11, 9)

# %%
maxx_intelligence_bad = bad[bad['Intelligence']==113] # maximum speed of bad in 100
maxx_intelligence_bad
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
#
#      Power  Combat  Total
# 386    100      28    277

# %%
min_intelligence_bad = bad[bad['Intelligence']==1] # maximum speed of bad in 100
min_intelligence_bad
# Out:
#                  Name Alignment  Intelligence  Strength  Speed  Durability  \
# 17               Ammo       bad             1         1      1           1
# 21             Angela       bad             1         1      1           1
# 27         Anti-Spawn       bad             1         1      1           1
# 67             Beetle       bad             1         1      1           1
# 75      Billy Kincaid       bad             1         1      1           1
# 78           Bird-Man       bad             1         1      1           1
# 79        Bird-Man II       bad             1         1      1           1
# 83       Black Abbott       bad             1         1      1           1
# 103          Blizzard       bad             1         1      1           1
# 104        Blizzard I       bad             1         1      1           1
# 109       Bloodwraith       bad             1         1      1           1
# ...

# %%
min_intelligence_bad.shape
# Out:
# (44, 9)

# %%
bad.sort_values(by=['Total'],ascending=False) # maximum numerical method top of the level
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
# ..              ...       ...           ...       ...    ...         ...
# 103        Blizzard       bad             1         1      1           1
# 349   Luke Campbell       bad             1         1      1           1
# 181        Darkside       bad             1         1      1           1
# 390          Moloch       bad             1         1      1           1
# 254     Goliath III       bad             1         1      1           1
#
#      Power  Combat  Total
# 535    100      85    579
# 242     94      95    579
# ...

# %%
bad.sort_values(by=['Total'],ascending=False).head() # maximum numerical method top of the level
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
#
#      Power  Combat  Total
# 535    100      85    579
# 242     94      95    579
# 16     100     100    575
# 203    100      80    546
# 201    100      90    545

# %%
bad_max_power = bad.sort_values(by=['Total'],ascending=False)
bad_max_power
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 535  Superboy-Prime       bad            94       100    100         100
# 242     General Zod       bad            94       100     96         100
# 16            Amazo       bad            75       100    100         100
# 203        Dormammu       bad            88        95     83         100
# 201        Doomsday       bad            88        80     67         120
# ..              ...       ...           ...       ...    ...         ...
# 103        Blizzard       bad             1         1      1           1
# 349   Luke Campbell       bad             1         1      1           1
# 181        Darkside       bad             1         1      1           1
# 390          Moloch       bad             1         1      1           1
# 254     Goliath III       bad             1         1      1           1
#
#      Power  Combat  Total
# 535    100      85    579
# 242     94      95    579
# ...

# %%
bad_cm_power = bad.sort_values(by=['Combat'],ascending=False)
bad_cm_power.head(10)
# Out:
#              Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 475    Sabretooth       bad            55        53     25          90     28
# 16          Amazo       bad            75       100    100         100    100
# 449  Ra's Al Ghul       bad           100        28     32          42     27
# 464     Rick Flag       bad            88        11     23          28     19
# 180      Darkseid       bad            88       100     23         100    100
# 360      Mandarin       bad           100        28     23          28     99
# 52           Bane       bad            88        53     23          56     51
# 242   General Zod       bad            94       100     96         100     94
# 4     Abomination       bad            63        80     53          90     55
# 26   Anti-Monitor       bad            88        90     38          90    100
#
#      Combat  Total
# 475     100    351
# 16      100    575
# 449     100    329
# 464      95    264
# ...

# %%
plt.figure(figsize=(10,5))
plt.bar(list(bad_max_power['Name'])[0:5],list(bad_max_power['Total'])[0:5],color=['Red','Green','Orange','Blue','Pink','Purple'])
plt.show()

# %%
#Making a histogram for speed for good superheroes
plt.figure(figsize=(10,3))
sns.histplot(good['Speed'])
plt.title('Distribution of Speed')
plt.xlabel('Speed')
plt.show()

# %%
#Making a histogram for combat for bad superheroes
plt.figure(figsize=(10,3))
sns.histplot(bad['Combat'])
plt.title('Distribution of Combat')
plt.xlabel('Combat')
plt.show()
